# %% [markdown]
# 4. Qual é o método de pagamento preferido pelos clientes mais longevos e com maior geração de receita para a companhia?
#
# 5. Existe concentração de *churn* ou de clientes de alto valor (`TotalCharges`) em cidades ou faixas de população específica?
#
# 6. O faturamento médio por cliente varia conforme a densidade populacional da região atendida (`Zip-Code` / `Population`)?
#
#
#
# > **Nota de acompanhamento:** Conforme as diretrizes do projeto, estas perguntas guiarão o desenvolvimento do pipeline. Perguntas que eventualmente não puderem ser respondidas devido a limitações técnicas não serão removidas desta seção, mas sim documentadas e discutidas na etapa de Autoavaliação final.
