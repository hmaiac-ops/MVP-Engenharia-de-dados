# %% [markdown]
# # Perguntas de Negócio
#
# 1. O modelo de contratação tem impacto na taxa de cancelamento (*churn*)?
# 2. Clientes de fibra ótica geram `TotalCharges` superior?
# 3. Serviços adicionais diminuem o *churn*?
